# %%
import pandas as pd
import json
import numpy as np
from khayyam import *
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from furl import furl
import psycopg2
import datetime
import pandas.io.sql as psql

db_username="Jay"
db_pass="Mehrad1"
db_host="127.0.0.1"
db_port="5432"
db_database="FinWisev12"
# Out:
# /home/levi/Desktop/Env/my/lib/python3.8/site-packages/khayyam/algorithms.py:18: UserWarning: The C extension is not available. Switching to fallback python pure algorithms,so it's about 1000X slower than C implementation of the algorithms.
#   warnings.warn(

# %%
def get_unconvertedIncreaseCapital(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."IncreaseCapitalConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllIncreaseCapital(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True
        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                

def get_unconvertedDisclosure(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."DisclosureConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllDisclosure(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                

def get_unconvertedInvit(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."AssemblyConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllInvit(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True 


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                

def get_unconvertedOrgClar(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."orgClarificationConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllOrgClar(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True 


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()

def get_unconvertedBoard(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."BoardChangeConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllBoard(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True 


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_Presheets_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                select COUNT(*) FROM codalraw."allrawReports" where "LetterCode"='ن-۱۰' and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."SheetsConverted")
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_Presheets_All():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                select COUNT(*) FROM codalraw."allrawReports" where "LetterCode"='ن-۱۰' and "HtmlUrl"!='' and "Available"=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()  
def get_Income_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                select COUNT(*) from codalraw."SheetsConverted" inner join codalraw."allrawReports" on "report_ID"="TracingNo" where ("Exist_Income"=False or "Exist_IncomeCons"=False or "Exist_IncomeComp"=False  or "Exist_IncomeCompCons"=False)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_Income_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted" inner join codalraw."allrawReports" on "report_ID"="TracingNo" where ("Exist_Income"=True or "Exist_IncomeCons"=True or "Exist_IncomeComp"=True  or "Exist_IncomeCompCons"=True)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close() 
def get_BS_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_Bs"=False or "Exist_bsCons"=False)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_BS_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_Bs"=True or "Exist_bsCons"=True)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close() 
def get_CF_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_Cf"=False or "Exist_cfCons"=False)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_CF_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_Cf"=True or "Exist_cfCons"=True)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()  
def get_Right_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_PropertyRight"=False or "Exist_PropertyRightCons"=False)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_Right_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."SheetsConverted"  where ("Exist_PropertyRight"=True or "Exist_PropertyRightCons"=True)
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()    
def get_PreMonthly_unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."allrawReports" where ("LetterCode"='ن-۳۰' or "LetterCode"='ن-۳۱')  
 and "TracingNo" not in (Select "report_ID" from monthly."PreMonthly") and "HasHtml"=True  and "HtmlUrl"!='' and "Available"=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                
def get_PreMonthly_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
               select COUNT(*) from codalraw."allrawReports" where ("LetterCode"='ن-۳۰' or "LetterCode"='ن-۳۱')  
 and "TracingNo"  in (Select "report_ID" from monthly."PreMonthly") and "HasHtml"=True  and "HtmlUrl"!='' and "Available"=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close() 
def get_NOTES_UNConverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select COUNT(*) from codalraw."SheetsConverted" inner join
            codalraw."allrawReports" on "report_ID"="TracingNo" where ("Exist_Interpret"=False )
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close() 
def get_NOTES_Converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select COUNT(*) from codalraw."SheetsConverted" inner join
            codalraw."allrawReports" on "report_ID"="TracingNo" where ("Exist_Interpret"=True )
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()                      
def get_MonthlyBanks_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Bank' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyBanks_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Bank' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()               
def get_MonthlyConstruction_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select Count(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Construction' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyConstruction_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select Count(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Construction' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()              
def get_MonthlyInsurance_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
              select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Insurance' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyInsurance_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
             select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Insurance' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_MonthlyInvestment_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                 select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Investment' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyInvestment_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
             select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Investment' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       




def get_MonthlyLeasing_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                 select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Leasing' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyLeasing_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
             select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Leasing' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()   
def get_MonthlyService_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                 select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Service' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyService_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
             select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Service' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()   
def get_MonthlyProduct_Unconverted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
                 select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Product' and P.converted=False
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()       
def get_MonthlyProduct_converted():
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""
             select COUNT(*)
            from monthly."PreMonthly" as P inner join codalraw."allrawReports" as R on P."report_ID"=R."TracingNo"
            WHERE P."Type"='Product' and P.converted=True
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()

# %%
def get_unconvertedBOURSECLAR(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True and "TracingNo" not in (select "report_ID" from codalraw."BourseClarificationConverted")


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()
def get_AllBOURSECLAR(i,j):
    try:
        connection = psycopg2.connect(user=db_username,
                                          password=db_pass,
                                          host=db_host,
                                          port=db_port,
                                          database=db_database)
        cursor = connection.cursor()
        df = psql.read_sql("""

        select COUNT(*) FROM codalraw."allrawReports" where ("LetterCode"='"""
                           +i+
                           """'OR "LetterCode"='"""+j+"""')and "HtmlUrl"!='' and "Available"=True


        
        """, connection)
        return df
    except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to read links", error)
    finally:
            if(connection):
                cursor.close()
                connection.close()

# %%
print('------------------------------IncreaseCapital--------******----------------------------------')   
listofAll=[
    'ن-۶۰',
    'ن-۶۱',
    'ن-۶۲',
    'ن-۶۳',
    'ن-۶۴',
    'ن-۶۵',
    'ن-۶۶',
    'ن-۶۷',
    'ن-۷۰',
    'ن-۷۱',
    'ن-۷۲',
    'ن-۷۳',    
]
for i in listofAll:
    if ',' not in i:
        print(i+'---UnconvertedRate: '+str(round(get_unconvertedIncreaseCapital(i,i).iloc[0]['count']/get_AllIncreaseCapital(i,i).iloc[0]['count']*100,2))+'%')
        print(i+'-------------------Unconverted: '+ str(get_unconvertedIncreaseCapital(i,i).iloc[0]['count']))
        print(i+'-------------------'+'All: '+str(get_AllIncreaseCapital(i,i).iloc[0]['count']))
        print('*****************************')
print('------------------------------Disclosure--------******----------------------------------')  
listofAll2=[
    'ن-۲۰',
    'ن-۲۱',
    'ن-۲۲',
    'ن-۲۴',
    'ن-۲۵',
    'ن-۲۶'
    
]
for i in listofAll2:
    print(i+'---UnconvertedRate: '+str(round(get_unconvertedDisclosure(i,i).iloc[0]['count']/get_AllDisclosure(i,i).iloc[0]['count']*100,2))+'%')
    print(i+'-------------------Unconverted: '+ str(get_unconvertedDisclosure(i,i).iloc[0]['count']))
    print(i+'-------------------'+'All: '+str(get_AllDisclosure(i,i).iloc[0]['count']))
    print('*****************************')
    
print('------------------------------BOURSE CLAR--------******----------------------------------')  
listofAll2=[
    'ف ب-۱',
    'ب-۱',
    'ف ب-۲',
    'ب-۲',
    'ف ب-۳',
    'ب-۳',
    'ف ب-۴',
    'ب-۴',
    'ب-۵',
    'ف ب-۵',
    'ف ب-۷',
    'ب-۷',
    'ف ب-۸',
    'ب-۸',
#     'ف ب-۹',
#     'ب-۹'
    
]
for i in listofAll2:
    print(i+'---UnconvertedRate: '+str(round(get_unconvertedBOURSECLAR(i,i).iloc[0]['count']/get_AllBOURSECLAR(i,i).iloc[0]['count']*100,2))+'%')
    print(i+'-------------------Unconverted: '+ str(get_unconvertedBOURSECLAR(i,i).iloc[0]['count']))
    print(i+'-------------------'+'All: '+str(get_AllBOURSECLAR(i,i).iloc[0]['count']))
    print('*****************************')

print('------------------------------------Assembly****----------------------------')   
listofAll4=[
    'ن-۵۰',
    'ن-۵۱',
    'ن-۵۲',
    'ن-۵۴',
    'ن-۵۵',
    'ن-۵۶',
    'ن-۵۷',
    'ن-۵۸'
   
]
for i in listofAll4:
    if ',' not in i:
        print(i+'---UnconvertedRate: '+str(round(get_unconvertedInvit(i,i).iloc[0]['count']/get_AllInvit(i,i).iloc[0]['count']*100,2))+'%')
        print(i+'-------------------Unconverted: '+ str(get_unconvertedInvit(i,i).iloc[0]['count']))
        print(i+'-------------------'+'All: '+str(get_AllInvit(i,i).iloc[0]['count']))
        print('*****************************')
print('--------------------ORG---------------')        
listofAll8=[
    'س-۵',
    'س-۶',
    'س-۷',
    'س-۸',
    'س-۹',
    'س-۱۲',
    'س-۱۳',
    'س-۱۴',
    'س-۱۵',
    
]
for i in listofAll8:
    if ',' not in i:
        print(i+'---UnconvertedRate: '+str(round(get_unconvertedOrgClar(i,i).iloc[0]['count']/get_AllOrgClar(i,i).iloc[0]['count']*100,2))+'%')
        print(i+'-------------------Unconverted: '+ str(get_unconvertedOrgClar(i,i).iloc[0]['count']))
        print(i+'-------------------'+'All: '+str(get_AllOrgClar(i,i).iloc[0]['count']))
        print('*****************************')
print('----------------------Board---------------------')
listofAll9=[

    'ن-۴۱',
    'ن-۴۵'
]
for i in listofAll9:

    if ',' not in i:
        print(i+'---UnconvertedRate: '+str(round(get_unconvertedBoard(i,i).iloc[0]['count']/get_AllBoard(i,i).iloc[0]['count']*100,2))+'%')
        print(i+'-------------------Unconverted: '+ str(get_unconvertedBoard(i,i).iloc[0]['count']))
        print(i+'-------------------'+'All: '+str(get_AllBoard(i,i).iloc[0]['count']))
        print('*****************************')
# Out:
# ------------------------------IncreaseCapital--------******----------------------------------
# ن-۶۰---UnconvertedRate: 0.0%
# ن-۶۰-------------------Unconverted: 0
# ن-۶۰-------------------All: 2039
# *****************************
# ن-۶۱---UnconvertedRate: 0.0%
# ن-۶۱-------------------Unconverted: 0
# ن-۶۱-------------------All: 1579
# *****************************
# ن-۶۲---UnconvertedRate: 0.6%
# ن-۶۲-------------------Unconverted: 10
# ن-۶۲-------------------All: 1665
# *****************************
# ن-۶۳---UnconvertedRate: 0.0%
# ن-۶۳-------------------Unconverted: 0
# ن-۶۳-------------------All: 81
# *****************************
# ن-۶۴---UnconvertedRate: 0.0%
# ن-۶۴-------------------Unconverted: 0
# ن-۶۴-------------------All: 1338
# *****************************
# ن-۶۵---UnconvertedRate: 0.0%
# ن-۶۵-------------------Unconverted: 0
# ن-۶۵-------------------All: 1073
# *****************************
# ن-۶۶---UnconvertedRate: 0.0%
# ن-۶۶-------------------Unconverted: 0
# ...

# %%
print('----------------------Sheets---------------------')  
print('---UnconvertedRate: '+str(round(get_Presheets_unconverted().iloc[0]['count']/get_Presheets_All().iloc[0]['count']*100,2))+'%')
print('-------------------Unconverted: '+ str(get_Presheets_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_Presheets_All().iloc[0]['count']))
print('*****************************')
print('----------------------Income---------------------')  
print('---UnconvertedRate: '+str(round(get_Income_unconverted().iloc[0]['count']/(get_Income_unconverted().iloc[0]['count']+get_Income_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_Income_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_Income_unconverted().iloc[0]['count']+get_Income_Converted().iloc[0]['count']))
print('****************************')
print('----------------------BalanceSheets---------------------')  
print('---UnconvertedRate: '+str(round(get_BS_unconverted().iloc[0]['count']/(get_BS_unconverted().iloc[0]['count']+get_BS_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_BS_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_BS_unconverted().iloc[0]['count']+get_BS_Converted().iloc[0]['count']))
print('*****************************')
print('----------------------CF---------------------')  
print('---UnconvertedRate: '+str(round(get_CF_unconverted().iloc[0]['count']/(get_CF_unconverted().iloc[0]['count']+get_CF_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_CF_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_CF_unconverted().iloc[0]['count']+get_CF_Converted().iloc[0]['count']))
print('*****************************')
print('----------------------RIGHTS---------------------')  
print('---UnconvertedRate: '+str(round(get_Right_unconverted().iloc[0]['count']/(get_Right_unconverted().iloc[0]['count']+get_Right_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_Right_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_Right_unconverted().iloc[0]['count']+get_Right_Converted().iloc[0]['count']))
print('*****************************')
print('----------------------Notes---------------------')  
print('---UnconvertedRate: '+str(round(get_NOTES_UNConverted().iloc[0]['count']/(get_NOTES_UNConverted().iloc[0]['count']+get_NOTES_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_NOTES_UNConverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_NOTES_UNConverted().iloc[0]['count']+get_NOTES_Converted().iloc[0]['count']))
print('*****************************')
# Out:
# ----------------------Sheets---------------------
# ---UnconvertedRate: 3.59%
# -------------------Unconverted: 3014
# -------------------All: 83991
# *****************************
# ----------------------Income---------------------
# ---UnconvertedRate: 1.8%
# -------------------Unconverted: 1415
# -------------------All: 78737
# ****************************
# ----------------------BalanceSheets---------------------
# ---UnconvertedRate: 2.17%
# -------------------Unconverted: 1586
# -------------------All: 73175
# *****************************
# ----------------------CF---------------------
# ---UnconvertedRate: 2.65%
# -------------------Unconverted: 1359
# -------------------All: 51336
# *****************************
# ----------------------RIGHTS---------------------
# ---UnconvertedRate: 41.94%
# -------------------Unconverted: 5941
# -------------------All: 14164
# *****************************
# ----------------------Notes---------------------
# ---UnconvertedRate: 23.17%
# ...

# %%
print(datetime.datetime.now())
print('----------------------PreMonthly---------------------')  
print('---UnconvertedRate: '+str(round(get_PreMonthly_unconverted().iloc[0]['count']/(get_PreMonthly_unconverted().iloc[0]['count']+get_PreMonthly_Converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_PreMonthly_unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_PreMonthly_unconverted().iloc[0]['count']+get_PreMonthly_Converted().iloc[0]['count']))
print('*****************************')
print('----------------------Bank_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyBanks_Unconverted().iloc[0]['count']/(get_MonthlyBanks_Unconverted().iloc[0]['count']+get_MonthlyBanks_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyBanks_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyBanks_Unconverted().iloc[0]['count']+get_MonthlyBanks_converted().iloc[0]['count']))
# print('*****************************')
print('----------------------Construction_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyConstruction_Unconverted().iloc[0]['count']/(get_MonthlyConstruction_Unconverted().iloc[0]['count']+get_MonthlyConstruction_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyConstruction_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyConstruction_Unconverted().iloc[0]['count']+get_MonthlyConstruction_converted().iloc[0]['count']))
print('*****************************')
print('----------------------Insurance_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyInsurance_Unconverted().iloc[0]['count']/(get_MonthlyInsurance_Unconverted().iloc[0]['count']+get_MonthlyInsurance_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyInsurance_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyInsurance_Unconverted().iloc[0]['count']+get_MonthlyInsurance_converted().iloc[0]['count']))
print('*****************************')
print('----------------------Investment_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyInvestment_Unconverted().iloc[0]['count']/(get_MonthlyInvestment_Unconverted().iloc[0]['count']+get_MonthlyInvestment_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyInvestment_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyInvestment_Unconverted().iloc[0]['count']+get_MonthlyInvestment_converted().iloc[0]['count']))
print('*****************************')


print('----------------------Leasing_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyLeasing_Unconverted().iloc[0]['count']/(get_MonthlyLeasing_Unconverted().iloc[0]['count']+get_MonthlyLeasing_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyLeasing_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyLeasing_Unconverted().iloc[0]['count']+get_MonthlyLeasing_converted().iloc[0]['count']))
print('*****************************')
print('----------------------Service_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyService_Unconverted().iloc[0]['count']/(get_MonthlyService_Unconverted().iloc[0]['count']+get_MonthlyService_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyService_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyService_Unconverted().iloc[0]['count']+get_MonthlyService_converted().iloc[0]['count']))
print('*****************************')
print('----------------------Production_Monthly---------------------')  
print('---UnconvertedRate: '+str(round(get_MonthlyProduct_Unconverted().iloc[0]['count']/(get_MonthlyProduct_Unconverted().iloc[0]['count']+get_MonthlyProduct_converted().iloc[0]['count'])*100,2))+'%')
print('-------------------Unconverted: '+ str(get_MonthlyProduct_Unconverted().iloc[0]['count']))
print('-------------------'+'All: '+str(get_MonthlyProduct_Unconverted().iloc[0]['count']+get_MonthlyProduct_converted().iloc[0]['count']))
print('*****************************')
# Out:
# 2022-07-31 05:05:22.596640
# ----------------------PreMonthly---------------------
# ---UnconvertedRate: 0.0%
# -------------------Unconverted: 0
# -------------------All: 49128
# *****************************
# ----------------------Bank_Monthly---------------------
# ---UnconvertedRate: 0.51%
# -------------------Unconverted: 4
# -------------------All: 778
# ----------------------Construction_Monthly---------------------
# ---UnconvertedRate: 5.83%
# -------------------Unconverted: 64
# -------------------All: 1097
# *****************************
# ----------------------Insurance_Monthly---------------------
# ---UnconvertedRate: 1.57%
# -------------------Unconverted: 15
# -------------------All: 956
# *****************************
# ----------------------Investment_Monthly---------------------
# ---UnconvertedRate: 47.48%
# -------------------Unconverted: 7669
# -------------------All: 16152
# *****************************
# ...
